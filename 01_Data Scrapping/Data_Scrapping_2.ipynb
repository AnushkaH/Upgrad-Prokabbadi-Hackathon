# %% [markdown]
# # Importing the libraries required for Web Scrapping and Data Processing

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver

# %%
driver= webdriver.Chrome("D:\\Documents\\Python Scripts\\chromedriver.exe")

# %%
driver.get('https://www.prokabaddi.com/stats/0-96-total-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

# %%
Team= soup.find_all('div', class_='mod-body')

# %% [markdown]
# # Scrapping data of Total Points

# %%
driver.get('https://www.prokabaddi.com/stats/49-96-total-points-scored-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-96-total-points-scored-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-96-total-points-scored-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-96-total-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-96-total-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-96-total-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-96-total-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Scored':Raid_pts})

# %% [markdown]
# # Data Scrapping for Total points conceded

# %%
driver.get('https://www.prokabaddi.com/stats/49-133-total-points-conceded-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_conceded_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Conceded':Raid_pts})
df_totalpts_conceded_Season7
# Out:
#    Rank                                               Team  \
# 0    1.  \n                    Puneri Paltan\n         ...
# 1    2.  \n                    Tamil Thalaivas\n       ...
# 2    3.  \n                    Dabang Delhi K.C.\n     ...
# 3    4.  \n                    Jaipur Pink Panthers\n  ...
# 4    4.  \n                    Bengaluru Bulls\n       ...
# 5    6.  \n                    Patna Pirates\n         ...
# 6    7.  \n                    Haryana Steelers\n      ...
# 7    8.  \n                    Bengal Warriors\n       ...
# 8    9.  \n                    Telugu Titans\n         ...
# 9   10.  \n                    Gujarat Fortunegiants\n ...
# 10  11.  \n                    U.P. Yoddha\n           ...
# 11  12.  \n                    U Mumba\n               ...
#
#    No of Matches Played Total Points Conceded
# 0                    20                   723
# 1                    20                   668
# 2                    20                   659
# 3                    20                   644
# 4                    19                   644
# 5                    19                   641
# 6                    19                   626
# 7                    20                   623
# 8                    18                   603
# 9                    20                   591
# 10                   18                   570
# 11                   19                   538

# %%
driver.get('https://www.prokabaddi.com/stats/26-133-total-points-conceded-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_conceded_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-133-total-points-conceded-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_conceded_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-133-total-points-conceded-statistics')
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_conceded_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-133-total-points-conceded-statistics')
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_conceded_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-133-total-points-conceded-statistics')
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_conceded_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-133-total-points-conceded-statistics')
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_totalpts_conceded_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Total Points Conceded':Raid_pts})

# %% [markdown]
# # Scrapping for Avg Points Scored

# %%
driver.get('https://www.prokabaddi.com/stats/49-140-avg-points-scored-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avgpts_scored_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-140-avg-points-scored-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avgpts_scored_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-140-avg-points-scored-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avgpts_scored_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-140-avg-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avgpts_scored_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-140-avg-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avgpts_scored_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-140-avg-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avgpts_scored_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Points Scored':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-140-avg-points-scored-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avgpts_scored_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Points Scored':Raid_pts})

# %% [markdown]
# # Scrapping for Successful Raids

# %%
driver.get('https://www.prokabaddi.com/stats/49-13-successful-raids-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_raid_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-13-successful-raids-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_raid_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-13-successful-raids-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_raid_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-13-successful-raids-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_raid_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-13-successful-raids-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_raid_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-13-successful-raids-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_raid_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-13-successful-raids-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_raid_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Raids':Raid_pts})

# %% [markdown]
# # Scrapping for Raid Points

# %%
driver.get('https://www.prokabaddi.com/stats/49-97-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_raid_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-97-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_raid_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-97-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_raid_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-97-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_raid_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-97-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_raid_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-97-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_raid_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-97-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_raid_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Raid Points':Raid_pts})

# %% [markdown]
# # Scrapping for Avg Raid Points

# %%
driver.get('https://www.prokabaddi.com/stats/49-98-avg-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_raidpts_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-98-avg-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_raidpts_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-98-avg-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_raidpts_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-98-avg-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_raidpts_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-98-avg-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_raidpts_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-98-avg-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_raidpts_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-98-avg-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_raidpts_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Raid Points':Raid_pts})

# %% [markdown]
# # Scrapping for Successful Tackles

# %%
driver.get('https://www.prokabaddi.com/stats/49-15-successful-tackles-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_tackles_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-15-successful-tackles-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_tackles_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-15-successful-tackles-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_tackles_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-15-successful-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_tackles_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-15-successful-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_tackles_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-15-successful-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_tackles_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-15-successful-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_succ_tackles_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Successful Tackles':Raid_pts})

# %% [markdown]
# # Scrapping for Tackle points

# %%
driver.get('https://www.prokabaddi.com/stats/49-95-tackle-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_tackle_pts_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-95-tackle-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_tackle_pts_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-95-tackle-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_tackle_pts_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-95-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_tackle_pts_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-95-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_tackle_pts_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-95-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_tackle_pts_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-95-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_tackle_pts_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Tackle Points':Raid_pts})

# %% [markdown]
# # Scrapping for avg tackle points

# %%
driver.get('https://www.prokabaddi.com/stats/49-99-avg-tackle-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_tackle_pts_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-99-avg-tackle-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_tackle_pts_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-99-avg-tackle-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_tackle_pts_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-99-avg-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_tackle_pts_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-99-avg-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_tackle_pts_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-99-avg-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_tackle_pts_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Tackle Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-99-avg-tackle-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_avg_tackle_pts_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Avg Tackle Points':Raid_pts})

# %% [markdown]
# # Scrapping for Super Raids

# %%
driver.get('https://www.prokabaddi.com/stats/49-134-super-raid-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_superraid_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-134-super-raid-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_superraid_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-134-super-raid-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_superraid_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-134-super-raid-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_superraid_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-134-super-raid-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_superraid_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-134-super-raid-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_superraid_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Raids':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-134-super-raid-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_superraid_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Raids':Raid_pts})

# %% [markdown]
# # Scrapping of Super Tackles

# %%
# %who_ls DataFrame

# %%
driver.get('https://www.prokabaddi.com/stats/49-20-super-tackles-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_supertackles_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-20-super-tackles-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_supertackles_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-20-super-tackles-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_supertackles_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-20-super-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_supertackles_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-20-super-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_supertackles_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-20-super-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_supertackles_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Tackles':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-20-super-tackles-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_supertackles_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Super Tackles':Raid_pts})

# %% [markdown]
# # Scrapping for Do or die raid points

# %%
driver.get('https://www.prokabaddi.com/stats/49-135-do-or-die-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_dodieraid_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Do or Die Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-135-do-or-die-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_dodieraid_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Do or Die Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-135-do-or-die-raid-points-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_dodieraid_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Do or Die Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-135-do-or-die-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_dodieraid_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Do or Die Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-135-do-or-die-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_dodieraid_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Do or Die Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-135-do-or-die-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_dodieraid_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Do or Die Raid Points':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-135-do-or-die-raid-points-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_dodieraid_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'Do or Die Raid Points':Raid_pts})

# %% [markdown]
# # Scrapping for All outs inflicted

# %%
driver.get('https://www.prokabaddi.com/stats/49-136-all-outs-inflicted-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_inflicted_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Out Inflicted':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-136-all-outs-inflicted-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_inflicted_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Out Inflicted':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-136-all-outs-inflicted-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_inflicted_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Out Inflicted':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-136-all-outs-inflicted-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_inflicted_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Out Inflicted':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-136-all-outs-inflicted-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_inflicted_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Out Inflicted':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-136-all-outs-inflicted-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_inflicted_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Out Inflicted':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-136-all-outs-inflicted-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_inflicted_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Out Inflicted':Raid_pts})

# %% [markdown]
# # Scrapping for all outs conceded

# %%
driver.get('https://www.prokabaddi.com/stats/49-137-all-outs-conceded-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_conceded_Season7= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Outs Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/26-137-all-outs-conceded-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_conceded_Season6= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Outs Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/8-137-all-outs-conceded-statistics')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,12):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,12):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,12):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,12):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_conceded_Season5= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Outs Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/4-137-all-outs-conceded-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_conceded_Season4= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Outs Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/3-137-all-outs-conceded-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_conceded_Season3= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Outs Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/2-137-all-outs-conceded-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_conceded_Season2= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Outs Conceded':Raid_pts})

# %%
driver.get('https://www.prokabaddi.com/stats/1-137-all-outs-conceded-statistics')

soup=BeautifulSoup (driver.page_source, 'lxml')

team=[]
for i in range(0,8):
    team.append(soup.find_all('div',class_='sipk-lb-playerName')[i].span.text)

No_of_matches=[]
for i in range(0,8):
    No_of_matches.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-matchedPlayed')[i].span.text)

Raid_pts=[]
for i in range(0,8):
    Raid_pts.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-raidPoints')[i].span.text)

Rank=[]
for i in range(0,8):
    Rank.append(soup.find_all('div',class_='sipk-lb-detailBlock sipk-lb-rank')[i].span.text)

df_allout_conceded_Season1= pd.DataFrame({'Rank':Rank, "Team": team, "No of Matches Played": No_of_matches, 'All Outs Conceded':Raid_pts})

# %%
lis=[df_allout_conceded_Season1,df_allout_inflicted_Season1,df_avg_raidpts_Season1,df_avg_tackle_pts_Season1,df_avgpts_scored_Season1,df_dodieraid_Season1,df_raid_Season1,df_succ_raid_Season1,df_succ_tackles_Season1,df_superraid_Season1,df_supertackles_Season1,df_tackle_pts_Season1,df_totalpts_Season1,df_totalpts_conceded_Season1]

# %%
from functools import partial,reduce

pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',500)

# %%
merge= partial(pd.merge, on=['Team'],how='inner')

# %%
df1= reduce(merge,lis)

# %%
#%who_ls DataFrame

# %%
lis2=[df_allout_conceded_Season2,df_allout_inflicted_Season2,df_avg_raidpts_Season2,df_avg_tackle_pts_Season2,df_avgpts_scored_Season2,df_dodieraid_Season2,df_raid_Season2,df_succ_raid_Season2,df_succ_tackles_Season2,df_superraid_Season2,df_supertackles_Season2,df_tackle_pts_Season2,df_totalpts_Season2,df_totalpts_conceded_Season2]
df2= reduce(merge,lis2)

# %%
lis3=[df_allout_conceded_Season3,df_allout_inflicted_Season3,df_avg_raidpts_Season3,df_avg_tackle_pts_Season3,df_avgpts_scored_Season3,df_dodieraid_Season3,df_raid_Season3,df_succ_raid_Season3,df_succ_tackles_Season3,df_superraid_Season3,df_supertackles_Season3,df_tackle_pts_Season3,df_totalpts_Season3,df_totalpts_conceded_Season3]
df3= reduce(merge,lis3)

# %%
lis4=[df_allout_conceded_Season4,df_allout_inflicted_Season4,df_avg_raidpts_Season4,df_avg_tackle_pts_Season4,df_avgpts_scored_Season4,df_dodieraid_Season4,df_raid_Season4,df_succ_raid_Season4,df_succ_tackles_Season4,df_superraid_Season4,df_supertackles_Season4,df_tackle_pts_Season4,df_totalpts_Season4,df_totalpts_conceded_Season4]
df4= reduce(merge,lis4)

# %%
lis5=[df_allout_conceded_Season5,df_allout_inflicted_Season5,df_avg_raidpts_Season5,df_avg_tackle_pts_Season5,df_avgpts_scored_Season5,df_dodieraid_Season5,df_raid_Season5,df_succ_raid_Season5,df_succ_tackles_Season5,df_superraid_Season5,df_supertackles_Season5,df_tackle_pts_Season5,df_totalpts_Season5,df_totalpts_conceded_Season5]
df5= reduce(merge,lis5)

# %%
lis6=[df_allout_conceded_Season6,df_allout_inflicted_Season6,df_avg_raidpts_Season6,df_avg_tackle_pts_Season6,df_avgpts_scored_Season6,df_dodieraid_Season6,df_raid_Season6,df_succ_raid_Season6,df_succ_tackles_Season6,df_superraid_Season6,df_supertackles_Season6,df_tackle_pts_Season6,df_totalpts_Season6,df_totalpts_conceded_Season6]
df6= reduce(merge,lis6)

# %%
lis7=[df_allout_conceded_Season7,df_allout_inflicted_Season7,df_avg_raidpts_Season7,df_avg_tackle_pts_Season7,df_avgpts_scored_Season7,df_dodieraid_Season7,df_raid_Season7,df_succ_raid_Season7,df_succ_tackles_Season7,df_superraid_Season7,df_supertackles_Season7,df_tackle_pts_Season7,df_totalpts_Season7,df_totalpts_conceded_Season7]
df7= reduce(merge,lis7)

# %%
df7['Year']='2019'

# %%
df6['Year']='2018'
df5['Year']='2017'
df4['Year']='2016'
df3['Year']='2015'
df2['Year']='2014'
df1['Year']='2013'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-2ad6b7ca1d60> in <module>
#       1 df7['Year']='2019'
# ----> 2 df6['Year']='2018'
#       3 df5['Year']='2017'
#       4 df4['Year']='2016'
#       5 df3['Year']='2015'
#
# NameError: name 'df6' is not defined

# %%
df_1= pd.concat([df1,df2], axis=0)
df_2= pd.concat([df_1,df3], axis=0)
df_3= pd.concat([df_2,df4], axis=0)
df_4= pd.concat([df_3,df5], axis=0)
df_5= pd.concat([df_4,df6], axis=0)

# %%
df_5.shape
# Out:
# (56, 44)

# %%
df_5.to_csv('Teamwise_data.csv',header= True)

# %%
df7
# Out:
#    Rank_x                                               Team  \
# 0      1.  \n                    Puneri Paltan\n         ...
# 1      2.  \n                    Tamil Thalaivas\n       ...
# 2      3.  \n                    Bengaluru Bulls\n       ...
# 3      4.  \n                    Jaipur Pink Panthers\n  ...
# 4      4.  \n                    Patna Pirates\n         ...
# 5      6.  \n                    Telugu Titans\n         ...
# 6      6.  \n                    U.P. Yoddha\n           ...
# 7      6.  \n                    Gujarat Fortunegiants\n ...
# 8      9.  \n                    Haryana Steelers\n      ...
# 9     10.  \n                    U Mumba\n               ...
# 10    11.  \n                    Dabang Delhi K.C.\n     ...
# 11    12.  \n                    Bengal Warriors\n       ...
#
#    No of Matches Played_x All Outs Conceded Rank_y No of Matches Played_y  \
# 0                      20                33    10.                     20
# 1                      20                30    11.                     20
# 2                      19                24     6.                     19
# 3                      20                23     9.                     20
# 4                      19                23     3.                     19
# 5                      18                22    11.                     18
# 6                      18                22     6.                     18
# 7                      20                22     6.                     20
# 8                      19                21     4.                     19
# 9                      19                20     5.                     19
# 10                     20                18     1.                     20
# 11                     20                17     1.                     20
#
#    All Out Inflicted Rank_x No of Matches Played_x Avg Raid Points Rank_y  \
# 0                 18     7.                     20            17.9     1.
# 1                 13    10.                     20           16.75    12.
# 2                 21     3.                     19           20.68     7.
# 3                 19     8.                     20           16.85     2.
# 4                 28     5.                     19           19.37     7.
# 5                 13     6.                     18           18.44     6.
# 6                 21    11.                     18           16.06     3.
# 7                 21    12.                     20              16     5.
# 8                 27     4.                     19           19.84     4.
# 9                 26     9.                     19           16.79    10.
# 10                34     1.                     20           21.85    11.
# 11                34     2.                     20            21.3     9.
#
#    No of Matches Played_y Avg Tackle Points Rank_x No of Matches Played_x  \
# 0                      20              11.6     5.                     20
# 1                      20              8.45    12.                     20
# 2                      19             10.05     3.                     19
# 3                      20             10.95     8.                     20
# 4                      19             10.05     6.                     19
# 5                      18             10.11     7.                     18
# 6                      18             10.67     9.                     18
# 7                      20             10.15    10.                     20
# 8                      19             10.26     4.                     19
# 9                      19              9.53    11.                     19
# 10                     20              9.35     1.                     20
# 11                     20               9.6     2.                     20
#
#    Avg Points Scored Rank_y No of Matches Played_y Do or Die Raid Points  \
# 0               29.5     6.                     20                    60
# 1              24.85     8.                     20                    54
# 2              30.73    12.                     19                    42
# 3               27.8     1.                     20                    73
# 4              29.42     4.                     19                    69
# 5              28.55    11.                     18                    44
# 6              26.72     2.                     18                    71
# 7              26.15     7.                     20                    59
# 8               30.1     2.                     19                    71
# 9              25.68     5.                     19                    66
# 10              31.2    10.                     20                    50
# 11              30.9     9.                     20                    53
#
#    Rank_x No of Matches Played_x Raid Points Rank_y No of Matches Played_y  \
# 0      6.                     20         358     5.                     20
# 1      9.                     20         331     8.                     20
# 2      3.                     19         393     3.                     19
# 3      7.                     20         337    10.                     20
# 4      5.                     19         368     4.                     19
# 5      8.                     18         332     7.                     18
# 6     12.                     18         289    12.                     18
# 7     10.                     20         320     8.                     20
# 8      4.                     19         377     5.                     19
# 9     11.                     19         308    11.                     19
# 10     1.                     20         437     1.                     20
# 11     2.                     20         426     2.                     20
#
#    Successful Raids Rank_x No of Matches Played_x Successful Tackles Rank_y  \
# 0               290     1.                     20                207     9.
# 1               265    12.                     20                155    12.
# 2               309     8.                     19                168     5.
# 3               261     2.                     20                189     7.
# 4               291     8.                     19                168     3.
# 5               273    11.                     18                162     4.
# 6               223     7.                     18                177    10.
# 7               265     3.                     20                187    10.
# 8               290     5.                     19                181     2.
# 9               246    10.                     19                163     7.
# 10              361     5.                     20                181     5.
# 11              340     4.                     20                182     1.
#
#    No of Matches Played_y Super Raids Rank_x No of Matches Played_x  \
# 0                      20           6     2.                     20
# 1                      20           4    10.                     20
# 2                      19           8     2.                     19
# 3                      20           7     1.                     20
# 4                      19          13     4.                     19
# 5                      18           9     5.                     18
# 6                      18           5     8.                     18
# 7                      20           5     6.                     20
# 8                      19          14     9.                     19
# 9                      19           7     6.                     19
# 10                     20           8    12.                     20
# 11                     20          15    11.                     20
#
#    Super Tackles Rank_y No of Matches Played_y Tackle Points Rank_x  \
# 0             25     1.                     20           232     4.
# 1             13    12.                     20           168    11.
# 2             25     7.                     19           191     3.
# 3             32     2.                     20           219     7.
# 4             23     7.                     19           191     6.
# 5             21    10.                     18           182    10.
# 6             16     5.                     18           192    12.
# 7             17     3.                     20           203     8.
# 8             14     4.                     19           195     5.
# 9             17    11.                     19           179     9.
# 10             8     9.                     20           187     1.
# 11            12     5.                     20           192     2.
#
#    No of Matches Played_x Total Points Scored Rank_y No of Matches Played_y  \
# 0                      20                 652     1.                     20
# 1                      20                 553     2.                     20
# 2                      19                 656     4.                     19
# 3                      20                 626     4.                     20
# 4                      19                 640     6.                     19
# 5                      18                 564     9.                     18
# 6                      18                 551    11.                     18
# 7                      20                 605    10.                     20
# 8                      19                 650     7.                     19
# 9                      19                 567    12.                     19
# 10                     20                 742     3.                     20
# 11                     20                 718     8.                     20
#
#    Total Points Conceded  Year
# 0                    723  2019
# 1                    668  2019
# 2                    644  2019
# 3                    644  2019
# 4                    641  2019
# 5                    603  2019
# 6                    570  2019
# 7                    591  2019
# 8                    626  2019
# 9                    538  2019
# 10                   659  2019
# 11                   623  2019

# %%
df7.to_csv('teamwise1_test.csv',header= True)
