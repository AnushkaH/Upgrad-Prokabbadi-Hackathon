# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver

# %%
pd.set_option('Display.max_columns',100)
pd.set_option('Display.max_rows',500)

# %%
driver= webdriver.Chrome("D:\\Documents\\Python Scripts\\chromedriver.exe")

# %%
driver.get('https://www.prokabaddi.com/teams/bengaluru-bulls-profile-1')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_Bangalore= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
driver.get('https://www.prokabaddi.com/teams/bengal-warriors-profile-4')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_Bengal= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
driver.get('https://www.prokabaddi.com/teams/dabang-delhi-kc-profile-2')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_delhi= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
driver.get('https://www.prokabaddi.com/teams/gujarat-fortunegiants-profile-31')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[29,30,31,32,33,34,35]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_gujarat= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5})

# %%
driver.get('https://www.prokabaddi.com/teams/haryana-steelers-profile-28')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[29,30,31,32,33,34,35]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_Haryana= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5})

# %%
driver.get('https://www.prokabaddi.com/teams/patna-pirates-profile-6')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_Patna= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
driver.get('https://www.prokabaddi.com/teams/puneri-paltan-profile-7')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_pune= pd.DataFrame({'Overall Info':gen_cols, 'Season7':season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
driver.get('https://www.prokabaddi.com/teams/tamil-thalaivas-profile-29')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[29,30,31,32,33,34,35]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_tamil= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5})

# %%
driver.get('https://www.prokabaddi.com/teams/telugu-titans-profile-8')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_telugu= pd.DataFrame({'Overall Info':gen_cols,'Season7': season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
driver.get('https://www.prokabaddi.com/teams/u-mumba-profile-5')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_mumbai= pd.DataFrame({'Overall Info':gen_cols,'Season7': season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
driver.get('https://www.prokabaddi.com/teams/up-yoddha-profile-30')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[29,30,31,32,33,34,35]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_UP= pd.DataFrame({'Overall Info':gen_cols,'Season7': season7, 'Season6':season6, 'Season5': season5 })

# %%
driver.get('https://www.prokabaddi.com/teams/jaipur-pink-panthers-profile-3')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')

gen_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(1,8)]
#raid_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(8,17)]
#tackle_cols=[soup.find_all('div', class_='si-data-block')[i]. text for i in range(17,25)]

lis_cols=[33,34,35,36,37,38,39]
overall= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
overall.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]

season7= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season7.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season6= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season6.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season5= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season5.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season4= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season4.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season3= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season3.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season2= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season2.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


season1= [soup.find_all('div', class_='si-data-block')[i]. text for i in lis_cols[0:5]]
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[5]]. text[2:4])
season1.append(soup.find_all('div', class_='si-data-block')[lis_cols[6]]. text[3:5])
lis_cols=[i+7 for i in lis_cols]


df1_jaipur= pd.DataFrame({'Overall Info':gen_cols, 'Season7': season7, 'Season6':season6, 'Season5': season5, 'Season4': season4, 'Season3':season3, 'Season2':season2,'Season1': season1})

# %%
who ls DataFrame

# %%
df1_Bangalore= df1_Bangalore.set_index('Overall Info').T
df1_Bengal= df1_Bengal.set_index('Overall Info').T
df1_Haryana= df1_Haryana.set_index('Overall Info').T
df1_Patna= df1_Patna.set_index('Overall Info').T

df1_delhi= df1_delhi.set_index('Overall Info').T
df1_gujarat= df1_gujarat.set_index('Overall Info').T
df1_jaipur= df1_jaipur.set_index('Overall Info').T
df1_mumbai= df1_mumbai.set_index('Overall Info').T
df1_pune= df1_pune.set_index('Overall Info').T
df1_tamil= df1_tamil.set_index('Overall Info').T
df1_telugu= df1_telugu.set_index('Overall Info').T

# %%
df1_UP= df1_UP.set_index('Overall Info').T

# %%
df1_Bangalore["Team"]="Bangalore"
df1_Bengal["Team"]= 'Bengal'
df1_Haryana['Team']="Haryana"
df1_Patna['Team']='Patna'
df1_UP['Team']='UP'
df1_delhi['Team']='Delhi'
df1_gujarat['Team']='Gujarat'
df1_jaipur['Team']='Jaipur'
df1_mumbai['Team']='Mumbai'
df1_pune['Team']='Pune'
df1_tamil['Team']='Tamil'
df1_telugu['Team']='Telugu'

# %%
new_df= pd.DataFrame()

# %%
a=[df1_Bangalore,
 df1_Bengal,
 df1_Haryana,
 df1_Patna,
 df1_gujarat,
 df1_delhi,
 df1_UP,
 df1_jaipur,
 df1_mumbai,
 df1_pune,
 df1_tamil,
 df1_telugu]

# %%
for item in a:
    new_df= pd.concat([new_df,item], axis=0)

# %%
new_df=new_df.reset_index()
new_df= new_df. sort_values('index')

# %%
new_df.to_csv('Overall Stats1.csv', header= True)

# %%
driver.get('https://www.prokabaddi.com/standings')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')
team= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(1,13)]

pts= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(1,13)]

s7= pd.DataFrame({'Team': team, 'Points': pts})

# %%
s7
# Out:
#                      Team Points  Year  If_Qualified to next round
# 0       Dabang Delhi K.C.     82  2019                           1
# 1         Bengal Warriors     78  2019                           1
# 2        Haryana Steelers     65  2019                           1
# 3                 U Mumba     59  2019                           1
# 4         Bengaluru Bulls     58  2019                           1
# 5             U.P. Yoddha     58  2019                           1
# 6    Jaipur Pink Panthers     52  2019                           0
# 7   Gujarat Fortunegiants     45  2019                           0
# 8           Puneri Paltan     42  2019                           0
# 9           Patna Pirates     40  2019                           0
# 10          Telugu Titans     39  2019                           0
# 11        Tamil Thalaivas     31  2019                           0

# %%
driver.get('https://www.prokabaddi.com/standings')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')
team= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(1,7)]
team1= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(8,14)]
team= team+team1

pts= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(1,7)]
pts1= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(8,14)]
pts= pts+pts1

s6= pd.DataFrame({'Team': team, 'Points': pts})

# %%
s6

# %%
driver.get('https://www.prokabaddi.com/standings')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')
team= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(1,7)]
team1= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(8,14)]
team= team+team1

pts= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(1,7)]
pts1= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(8,14)]
pts= pts+pts1

s5= pd.DataFrame({'Team': team, 'Points': pts})

# %%
s5

# %%
driver.get('https://www.prokabaddi.com/standings')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')
team= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(1,9)]

pts= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(1,9)]

s4= pd.DataFrame({'Team': team, 'Points': pts})

# %%
s4

# %%
driver.get('https://www.prokabaddi.com/standings')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')
team= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(1,9)]

pts= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(1,9)]

s3= pd.DataFrame({'Team': team, 'Points': pts})

# %%
driver.get('https://www.prokabaddi.com/standings')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')
team= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(1,9)]

pts= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(1,9)]

s2= pd.DataFrame({'Team': team, 'Points': pts})

# %%
driver.get('https://www.prokabaddi.com/standings')

# %%
soup=BeautifulSoup (driver.page_source, 'lxml')
team= [soup.find_all('div', class_='sipk-table-col sipk-team')[i].span.text for i in range(1,9)]

pts= [soup.find_all('div', class_='sipk-table-col sipk-points')[i].span.text for i in range(1,9)]

s1= pd.DataFrame({'Team': team, 'Points': pts})

# %%
s6['Year']= 2018
s5['Year']= 2017
s4['Year']= 2016
s3['Year']= 2015
s2['Year']= 2014
s1['Year']= 2013

# %%
s7['Year']= 2019
elim_1=[]
for item in range(12):
    if item in [0,1,2,3,4,5]:
        elim_1.append(1)
    else:
        elim_1.append(0)
s7['If_Qualified to next round']= elim_1

# %%
elim=[]
for item in range(12):
    if item in [0,1,2,6,7,8]:
        elim.append(1)
    else:
        elim.append(0)

# %%
elim1=[]
for item in range(8):
    if item in [0,1,2,3]:
        elim1.append(1)
    else:
        elim1.append(0)

# %%
s6['If_Qualified to next round']= elim
s5['If_Qualified to next round']= elim
s4['If_Qualified to next round']= elim1
s3['If_Qualified to next round']= elim1
s2['If_Qualified to next round']= elim1
s1['If_Qualified to next round']= elim1

# %%
#new_df1= pd.DataFrame()
#b=[s6,s5,s4,s3,s2,s1]
#for item in b:
    #new_df1= pd.concat([new_df1,item], axis=0)

# %%
#new_df1.to_csv('Points.csv', header= True)

# %%
s7.to_csv('Points1.csv', header= True)
